# %% [markdown]
# <a href="https://colab.research.google.com/github/kazuto-abe/Unit3/blob/main/weekendHW_database_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Scenario
#
# Conside the following data from a school:
#
# | Student Name  | Fees Paid | Date of Birth | Address                             | Subject 1              | Subject 2                 | Subject 3          | Subject 4 | Teacher Name   | Teacher Address               | Course Name      |
# |---------------|-----------|---------------|-------------------------------------|------------------------|---------------------------|--------------------|-----------|----------------|-------------------------------|------------------|
# | John Smith    | 18-Jul-00 | 04-Aug-91     | 3 Main Street, North Boston 56125   | Economics 1 (Business) | Biology 1 (Science)       |                    |           | James Peterson | 44 March Way, Glebe 56100     | Economics        |
# | Maria Griffin | 14-May-01 | 10-Sep-92     | 16 Leeds Road, South Boston 56128   | Biology 1 (Science)    | Business Intro (Business) | Programming 2 (IT) |           | James Peterson | 44 March Way, Glebe 56100     | Computer Science |
# | Susan Johnson | 03-Feb-01 | 13-Jan-91     | 21 Arrow Street, South Boston 56128 | Biology 2 (Science)    |                           |                    |           | Sarah Francis  |                               | Medicine         |
# | Matt Long     | 29-Apr-02 | 25-Apr-92     | 14 Milk Lane,Â South Boston 56128   |                        |                           |                    |           | Shane Cobson   | 105 Mist Road, Faulkner 56410 | Dentistry        |
#
# ## Tasks
#
# 1. Normalize this table up to **3NF** [(see slides from class here)](https://https://docs.google.com/presentation/d/1sADUiD8YFt88YvV8UyHVhhPe7ks8K8Xpp3y-WPDJ2zc/edit#slide=id.p)
# 1. Create the ER diagram for the normalized database.
#
#
#
# ##[HL]
# 1. Research the SQl commands that are required for the operations CREATE, SELECT,and INSERT.
#
# 1. [Challenge] Using PyCharm you can create databases. Create a simple SQLite file and create the database in the first part. Try to insert the values in the **Table 1**. Schedule a meeting if you want me to show you how to start the database in Pycharm.
#
# ##Study Material
# [1] Short tutorial and easy read about Normalization [Guru99](https://www.guru99.com/database-normalization.html)
#
# [2] Short video tutorial on SQL by [Danielle The](https://www.youtube.com/watch?v=27axs9dO7AE)

# %% [markdown]
# **First Normal Form (1NF)**
#
# | id |  Student Name | Fees Paid | Date of Birth |        Address       |        Subject1        |          Subject2         |      Subject3      | Subject4 |  Teacher Name  | Teacher Address |    Course Name   |
# |:--:|:-------------:|:---------:|:-------------:|:--------------------:|:----------------------:|:-------------------------:|:------------------:|:--------:|:--------------:|:---------------:|:----------------:|
# |  1 |   John Smith  | 18-Jul-00 |   04-Aug-91   |     3 Main Street    | Economics 1 (Business) |    Biology 1 (Science)    |                    |          | James Peterson |   44 March Way  |     Economics    |
# |  2 |   John Smith  | 18-Jul-00 |   04-Aug-91   |     3 Main Street    | Economics 1 (Business) |    Biology 1 (Science)    |                    |          | James Peterson |   Glebe 56100   |     Economics    |
# |  3 |   John Smith  | 18-Jul-00 |   04-Aug-91   |  North Boston 56125  | Economics 1 (Business) |    Biology 1 (Science)    |                    |          | James Peterson |   44 March Way  |     Economics    |
# |  4 |   John Smith  | 18-Jul-00 |   04-Aug-91   |  North Boston 56125  | Economics 1 (Business) |    Biology 1 (Science)    |                    |          | James Peterson |   Glebe 56100   |     Economics    |
# |  5 | Maria Griffin | 14-May-01 |   10-Sep-92   |     16 Leeds Road    |   Biology 1 (Science)  | Business Intro (Business) | Programming 2 (IT) |          | James Peterson |   44 March Way  | Computer Science |
# |  6 | Maria Griffin | 14-May-01 |   10-Sep-92   |     16 Leeds Road    |   Biology 1 (Science)  | Business Intro (Business) | Programming 2 (IT) |          | James Peterson |   Glebe 56100   | Computer Science |
# |  7 | Maria Griffin | 14-May-01 |   10-Sep-92   |  South Boston 56128  |   Biology 1 (Science)  | Business Intro (Business) | Programming 2 (IT) |          | James Peterson |   44 March Way  | Computer Science |
# |  8 | Maria Griffin | 14-May-01 |   10-Sep-92   |  South Boston 56128  |   Biology 1 (Science)  | Business Intro (Business) | Programming 2 (IT) |          | James Peterson |   Glebe 56100   | Computer Science |
# |  9 | Susan Johnson | 03-Feb-01 |   13-Jan-91   |    21 Arrow Street   |   Biology 2 (Science)  |                           |                    |          |  Sarah Francis |                 |     Medicine     |
# | 10 | Susan Johnson | 03-Feb-01 |   13-Jan-91   |  South Boston 56128  |   Biology 2 (Science)  |                           |                    |          |  Sarah Francis |                 |     Medicine     |
# | 11 |   Matt Long   | 29-Apr-02 |   25-Apr-92   |     14 Milk Lane     |                        |                           |                    |          |  Shane Cobson  |  105 Mist Road  |     Dentistry    |
# | 12 |   Matt Long   | 29-Apr-02 |   25-Apr-92   |     14 Milk Lane     |                        |                           |                    |          |  Shane Cobson  |  Faulkner 56410 |     Dentistry    |
# | 13 |   Matt Long   | 29-Apr-02 |   25-Apr-92   | Â South Boston 56128 |                        |                           |                    |          |  Shane Cobson  |  105 Mist Road  |     Dentistry    |
# | 14 |   Matt Long   | 29-Apr-02 |   25-Apr-92   | Â South Boston 56128 |                        |                           |                    |          |  Shane Cobson  |  Faulkner 56410 |     Dentistry    |
#
# **Second Normal Form (2NF)**
#
# *Table 1 (Unnormalized): *
#
# | Student_id |  Student Name | Fees Paid | Date of Birth |               Address               |        Subject1        |          Subject2         |      Subject3      | Subject4 |  Teacher Name  |        Teacher Address        |    Course Name   |
# |:----------:|:-------------:|:---------:|:-------------:|:-----------------------------------:|:----------------------:|:-------------------------:|:------------------:|:--------:|:--------------:|:-----------------------------:|:----------------:|
# |      1     |   John Smith  | 18-Jul-00 |   04-Aug-91   |  3 Main Street, North Boston 56125  | Economics 1 (Business) |    Biology 1 (Science)    |                    |          | James Peterson |   44 March Way, Glebe 56100   |     Economics    |
# |      2     | Maria Griffin | 14-May-01 |   10-Sep-92   |  16 Leeds Road, South Boston 56128  | Biology 1 (Science)    | Business Intro (Business) | Programming 2 (IT) |          | James Peterson |   44 March Way, Glebe 56100   | Computer Science |
# |      3     | Susan Johnson | 03-Feb-01 |   13-Jan-91   | 21 Arrow Street, South Boston 56128 |   Biology 2 (Science)  |                           |                    |          |  Sarah Francis |                               |     Medicine     |
# |      4     |   Matt Long   | 29-Apr-02 |   25-Apr-92   |  14 Milk Lane,Â South Boston 56128  |                        |                           |                    |          |  Shane Cobson  | 105 Mist Road, Faulkner 56410 |     Dentistry    |
#
# *Table 2 (address table): *
#
# | id | Student_id |        Address       | Teacher Address |
# |:--:|:----------:|:--------------------:|:---------------:|
# |  1 |      1     |     3 Main Street    |   44 March Way  |
# |  2 |      1     |     3 Main Street    |   Glebe 56100   |
# |  3 |      1     |  North Boston 56125  |   44 March Way  |
# |  4 |      1     |  North Boston 56125  |   Glebe 56100   |
# |  5 |      2     |     16 Leeds Road    |   44 March Way  |
# |  6 |      2     |     16 Leeds Road    |   Glebe 56100   |
# |  7 |      2     |  South Boston 56128  |   44 March Way  |
# |  8 |      2     |  South Boston 56128  |   Glebe 56100   |
# |  9 |      3     |    21 Arrow Street   |                 |
# | 10 |      3     |  South Boston 56128  |                 |
# | 11 |      4     |     14 Milk Lane     |  105 Mist Road  |
# | 12 |      4     |     14 Milk Lane     |  Faulkner 56410 |
# | 13 |      4     | Â South Boston 56128 |  105 Mist Road  |
# | 14 |      4     | Â South Boston 56128 |  Faulkner 56410 |
#
# **Third Normal Form (3NF)**
#
# *Student Table:*
#
# | Student_id |  Student Name | Date of Birth |
# |:----------:|:-------------:|:-------------:|
# |      1     |   John Smith  |   04-Aug-91   |
# |      2     | Maria Griffin |   10-Sep-92   |
# |      3     | Susan Johnson |   13-Jan-91   |
# |      4     |   Matt Long   |   25-Apr-92   |
#
# *Subject Table*
#
# | student_id |   Subject1  |    Subject2    |    Subject3   | Subject4 |
# |:----------:|:-----------:|:--------------:|:-------------:|:--------:|
# |      1     | Economics 1 |    Biology 1   |               |          |
# |      2     |  Biology 1  | Business Intro | Programming 2 |          |
# |      3     |  Biology 2  |                |               |          |
# |      4     |             |                |               |          |
#
#
# *Course info Table*
#
# | student_id |  Fee paid |  Teacher Name  |    Course Name   |
# |:----------:|:---------:|:--------------:|:----------------:|
# |      1     | 18-Jul-00 | James Peterson |     Economics    |
# |      2     | 14-May-01 | James Peterson | Computer Science |
# |      3     | 03-Feb-01 |  Sarah Francis |     Medicine     |
# |      4     | 29-Apr-02 |  Shane Cobson  |     Dentistry    |
#
#
# **ER diagram based on the table above**
#
# ![Weekend HW - ER diagram (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## HL homework
#
# **Research the SQl commands that are required for the operations CREATE, SELECT,and INSERT.**
#
# ### CREATE
#
# *Syntax*
# ```
# CREATE TABLE table_name (
#     column1 datatype,
#     column2 datatype,
#     column3 datatype,
#    ....
# );
# ```
# The column parameters specify the names of the columns of the table.
#
# The datatype parameter specifies the type of data the column can hold (e.g. varchar, integer, date, etc.).
#
# ### SELECT
# The SELECT statement is used to select data from a database.
# The data returned is stored in a result table, called the result-set.
#
# *Syntax*
#
# ```
# SELECT column1, column2, ...
# FROM table_name;
# ```
# Here, column1, column2, ... are the field names of the table I want to select data from. If I want to select all the fields available in the table, use the following syntax:
#
# ```
# SELECT * FROM table_name;
# ```
#
# ### INSERT 1
# The INSERT INTO statement is used to insert new records in a table.
#
#
# It is possible to write the INSERT INTO statement in two ways.
# The first way specifies both the column names and the values to be inserted:
#
# *Syntax*
# ```
# INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);
# ```
#
# ### INSERT 2
# If I am adding values for all the columns of the table, I do not need to specify the column names in the SQL query. However, make sure the order of the values is in the same order as the columns in the table. The INSERT INTO syntax would be as follows:
#
# *Syntax*
#
# ```
# INSERT INTO table_name
# VALUES (value1, value2, value3, ...);
# ```
# ### INSERT (into select statement)
# The INSERT INTO SELECT statement copies data from one table and inserts it into another table.
#
# INSERT INTO SELECT requires that data types in source and target tables match
# The existing records in the target table are unaffected
#
# Copy all columns from one table to another table:
#
# ```
# INSERT INTO table2
# SELECT * FROM table1
# WHERE condition;
# ```
#
# Copy only some columns from one table into another table:
#
# ```
# INSERT INTO table2 (column1, column2, column3, ...)
# SELECT column1, column2, column3, ...
# FROM table1
# WHERE condition;
# ```

# %% [markdown]
# **[Challenge] Using PyCharm you can create databases. Create a simple SQLite file and create the database in the first part. Try to insert the values in the Table 1.**
#
# Since Pycharm does not work really well, I will figure out and get this done as soon as possibe.
#
# My approgies for the inconvinience.
